# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sentence_transformers import SentenceTransformer
import json

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
data = []
with open("multinli_1.0_train.jsonl", "r") as f:
    for line in f:
        data.append(json.loads(line))

# %%
len(data)
# Out:
# 392702

# %%
extracted_data = [{'sentence1': item['sentence1'], 

                   'sentence2': item['sentence2'], 

                   'gold_label': item['gold_label']} 

                  for item in data if item['gold_label'] in ['neutral', 'entailment', 'contradiction']]

# Convertir en DataFrame pour simplifier le traitement

df = pd.DataFrame(extracted_data)

# Aperçu des données extraites

df.head()
# Out:
#                                            sentence1  \
# 0  Conceptually cream skimming has two basic dime...
# 1  you know during the season and i guess at at y...
# 2  One of our number will carry out your instruct...
# 3  How do you know? All this is their information...
# 4  yeah i tell you what though if you go price so...
#
#                                            sentence2  gold_label
# 0  Product and geography are what make cream skim...     neutral
# 1  You lose the things to the following level if ...  entailment
# 2  A member of my team will execute your orders w...  entailment
# 3                  This information belongs to them.  entailment
# 4           The tennis shoes have a range of prices.     neutral

# %%
df_subset = df.sample(n=10000, random_state=42)

# %%
df_subset["embedding1"] = df_subset["sentence1"].apply(lambda x: model.encode(x, convert_to_numpy=True))
df_subset["embedding2"] = df_subset["sentence2"].apply(lambda x: model.encode(x, convert_to_numpy=True))

# %%
df_subset.to_parquet("dataset_with_embeddings.parquet", index=False)

# %%
df_subset["cosine_similarity"] = df_subset.apply(lambda row: cosine_similarity([row["embedding1"]], [row["embedding2"]])[0][0], axis=1)

# %%
df_subset
# Out:
#                                                 sentence1  \
# 155219                                  That's all right.
# 327538              Televisions are expensive these days.
# 325456  The colonial porte cochre sets the tone for Wa...
# 341461                                  and you just sift
# 54698   You think there's somethin' in all that talk T...
# ...                                                   ...
# 26259                         But I never went after him.
# 6705    it's uh it's kind of unusual book it's a lot a...
# 196700  (I learned this from the book Succeeding Gener...
# 313511  The Nonomiya Shrine is uniquely renowned for i...
# 30137         OMB reviewed the rule under Executive Order
#
#                                                 sentence2     gold_label  \
# 155219                                       That's fine.     entailment
# 327538  Televisions cost $200 when you purchase them f...        neutral
# 325456  The colonial porte coche on the front of the p...        neutral
# 341461                                  Don't sift, ever.  contradiction
# 54698   Topham had supported the talk due to his own d...        neutral
# ...                                                   ...            ...
# 26259        I never followed him, said the investigator.        neutral
# 6705           The book is unusual, but it is very good.         neutral
# 196700  Robert Haveman and the Grinch wrote "How to St...  contradiction
# 313511  The old culture of Japanese emperors had a gre...        neutral
# 30137   OMB failed to review the rule but decided upon...  contradiction
#
#                                                embedding1  \
# 155219  [0.016657539, 0.01060511, -0.050037496, -0.079...
# 327538  [0.05825889, 0.017244086, 0.060712803, -0.0311...
# 325456  [0.041701563, 0.016567806, -0.054379493, 0.007...
# 341461  [0.09222918, -0.035314932, 0.07395715, 0.03412...
# 54698   [-0.071036026, -0.061390392, 0.037302133, -0.0...
# ...                                                   ...
# 26259   [0.078442946, 0.022416787, -0.019123346, -0.00...
# 6705    [-0.029462632, 0.04509958, -0.015067618, 0.031...
# 196700  [-0.002023627, 0.004648458, -0.025176905, 0.02...
# 313511  [0.05340124, 0.061979506, -0.04517284, 0.01702...
# 30137   [-0.014626482, 0.08435352, 0.07805755, -0.0504...
#
#                                                embedding2  cosine_similarity
# 155219  [-0.0507622, -0.05900257, -0.076395094, -0.025...           0.609108
# 327538  [-0.04066672, 0.01306669, 0.029700672, -0.0778...           0.711511
# 325456  [0.100035, 0.03889193, 0.055443026, -0.0165682...           0.510867
# 341461  [0.04434778, -0.0026965349, 0.074316286, -0.00...           0.702823
# 54698   [0.046486303, 0.0028046842, 0.02795006, -0.036...           0.558429
# ...                                                   ...                ...
# 26259   [0.044823203, 0.114247605, -0.038013626, 0.031...           0.631499
# 6705    [-0.041380197, -0.0031413352, -6.911745e-05, 0...           0.620203
# 196700  [-0.10460997, 0.104579404, -0.044954475, 0.016...           0.261064
# 313511  [-0.05257546, 0.04215894, 0.0049503576, -0.028...           0.341712
# 30137   [0.0050079003, 0.08760196, -0.014337945, -0.04...           0.720313
#
# [10000 rows x 6 columns]

# %%
df_subset["euclidian_distance"] = df_subset.apply(lambda row: euclidean_distances([row["embedding1"]], [row["embedding2"]])[0][0], axis=1)
